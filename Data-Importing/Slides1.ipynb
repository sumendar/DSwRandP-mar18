# %% [markdown]
# # Table of Contents
#  <p><div class="lev2 toc-item"><a href="#Import-data-from-excel-files" data-toc-modified-id="Import-data-from-excel-files-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Import data from excel files</a></div><div class="lev3 toc-item"><a href="#Using-XLConnect-package" data-toc-modified-id="Using-XLConnect-package-0.1.1"><span class="toc-item-num">0.1.1&nbsp;&nbsp;</span>Using XLConnect package</a></div><div class="lev3 toc-item"><a href="#Using-xlsx-Package" data-toc-modified-id="Using-xlsx-Package-0.1.2"><span class="toc-item-num">0.1.2&nbsp;&nbsp;</span>Using xlsx Package</a></div><div class="lev3 toc-item"><a href="#Using-Readxl-Package" data-toc-modified-id="Using-Readxl-Package-0.1.3"><span class="toc-item-num">0.1.3&nbsp;&nbsp;</span>Using Readxl Package</a></div><div class="lev2 toc-item"><a href="#Importing-XML,-JSON-data-into-R" data-toc-modified-id="Importing-XML,-JSON-data-into-R-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Importing XML, JSON data into R</a></div><div class="lev2 toc-item"><a href="#Importing-Data-From-HTML-Tables-Into-R" data-toc-modified-id="Importing-Data-From-HTML-Tables-Into-R-0.3"><span class="toc-item-num">0.3&nbsp;&nbsp;</span>Importing Data From HTML Tables Into R</a></div><div class="lev3 toc-item"><a href="#Using-httr-packages" data-toc-modified-id="Using-httr-packages-0.3.1"><span class="toc-item-num">0.3.1&nbsp;&nbsp;</span>Using httr packages</a></div><div class="lev3 toc-item"><a href="#Using-rvest-package-(web-scrapping)" data-toc-modified-id="Using-rvest-package-(web-scrapping)-0.3.2"><span class="toc-item-num">0.3.2&nbsp;&nbsp;</span>Using rvest package (web scrapping)</a></div><div class="lev4 toc-item"><a href="#Import-data-from-wikipedia-(Scrape-an-HTML-Table)" data-toc-modified-id="Import-data-from-wikipedia-(Scrape-an-HTML-Table)-0.3.2.1"><span class="toc-item-num">0.3.2.1&nbsp;&nbsp;</span>Import data from wikipedia (Scrape an HTML Table)</a></div><div class="lev4 toc-item"><a href="#Import-data-from-wikipedia-(Using-xpath)" data-toc-modified-id="Import-data-from-wikipedia-(Using-xpath)-0.3.2.2"><span class="toc-item-num">0.3.2.2&nbsp;&nbsp;</span>Import data from wikipedia (Using xpath)</a></div><div class="lev2 toc-item"><a href="#Importing-Data-From-Other-Statistical-softwares" data-toc-modified-id="Importing-Data-From-Other-Statistical-softwares-0.4"><span class="toc-item-num">0.4&nbsp;&nbsp;</span>Importing Data From Other Statistical softwares</a></div><div class="lev3 toc-item"><a href="#haven-package" data-toc-modified-id="haven-package-0.4.1"><span class="toc-item-num">0.4.1&nbsp;&nbsp;</span>haven package</a></div><div class="lev4 toc-item"><a href="#From-SAS" data-toc-modified-id="From-SAS-0.4.1.1"><span class="toc-item-num">0.4.1.1&nbsp;&nbsp;</span>From SAS</a></div><div class="lev4 toc-item"><a href="#From-Stata" data-toc-modified-id="From-Stata-0.4.1.2"><span class="toc-item-num">0.4.1.2&nbsp;&nbsp;</span>From Stata</a></div><div class="lev4 toc-item"><a href="#From-SPSS" data-toc-modified-id="From-SPSS-0.4.1.3"><span class="toc-item-num">0.4.1.3&nbsp;&nbsp;</span>From SPSS</a></div><div class="lev3 toc-item"><a href="#foreign-package" data-toc-modified-id="foreign-package-0.4.2"><span class="toc-item-num">0.4.2&nbsp;&nbsp;</span>foreign package</a></div><div class="lev3 toc-item"><a href="#Hmisc-package" data-toc-modified-id="Hmisc-package-0.4.3"><span class="toc-item-num">0.4.3&nbsp;&nbsp;</span>Hmisc package</a></div>

# %% [markdown]
# ## Import data from excel files

# %% [markdown]
# ### Using XLConnect package

# %%
#install.packages("XLConnect", repos = "http://cran.us.r-project.org")
library(XLConnect) #lib.loc="C:/Users/Suman/Documents/R/win-library/3.4")

 
# Download an Excel file from the internet
# url <- "http://miraisolutions.files.wordpress.com/"
# path <- "2013/01/"
# file.name <- "example.xlsx"
# download.file(paste(url, path, file.name, sep = ""), file.name)
 
# Load the workbook
wb <- XLConnect::loadWorkbook("data/latitude.xlsx")
 
# Read data from a target section of the worksheet and print
my.data <- readWorksheet(wb, sheet = "1700", startRow = 10, startCol = 1, 
                         endRow = 42, endCol = 2)
print(my.data)
# Out:
#       Antigua.and.Barbuda   X17.072
# 1               Argentina -36.67600
# 2                 Armenia  40.25400
# 3                   Aruba  12.51300
# 4               Australia -32.21900
# 5                 Austria  48.23100
# 6              Azerbaijan  40.35200
# 7                 Bahamas  24.70000
# 8                 Bahrain  26.02400
# 9              Bangladesh  23.88000
# 10               Barbados  13.17900
# 11                Belarus  53.54709
# 12                Belgium  50.83700
# 13                 Belize  17.84300
# 14                  Benin   6.36400
# 15                Bermuda  32.21700
# 16                 Bhutan  27.47900
# 17                Bolivia -15.19000
# 18 Bosnia and Herzegovina  44.17501
# 19               Botswana -21.53600
# 20                 Brazil -19.55700
# 21 British Virgin Islands  18.50000
# 22                 Brunei   4.50100
# 23               Bulgaria  42.07300
# 24           Burkina Faso  12.04900
# 25                Burundi  -3.36500
# ...

# %% [markdown]
# ### Using xlsx Package

# %%
#install.packages("xlsx", repos = "http://cran.us.r-project.org")
# Use xlsx package
library("xlsx")
my_data <- read.xlsx("data/cities.xlsx", sheetName = "year_2000")
my_data
my_data <- read.xlsx2("data/cities.xlsx", sheetName = "year_1990")  # Prefer the read.xlsx2() over read.xlsx(), it’s significantly faster for large dataset.
my_data
# Out:
#   Capital   Population
# 1 New York  17800000
# 2 Berlin     3382169
# 3 Madrid     2938723
# 4 Stockholm  1942362
# 5 NA              NA
# 6 NA              NA
# 7 NA              NA
# 8 NA              NA
# 9 NA              NA
#   Capital   Population
# 1 New York  16044000
# 2 Berlin    3433695
# 3 Madrid    3010492
# 4 Stockholm 1683713

# %% [markdown]
# ### Using Readxl Package

# %%
# Use readxl package to read xls|xlsxl
#install.packages("readxl") 
library(readxl)
excel_sheets("data/cities.xlsx") 
my_data<-read_excel("data/cities.xlsx")
my_data
read_excel("data/cities.xlsx", sheet = 2) 
read_excel("data/cities.xlsx", sheet = "year_2000")
# col_names = FALSE: R assigns names itself 
# col_names = character vector: manually specify
# Out:
# [1] "year_1990" "year_2000"
#   Capital   Population
# 1 New York  16044000
# 2 Berlin     3433695
# 3 Madrid     3010492
# 4 Stockholm  1683713
#   Capital   Population
# 1 New York  17800000
# 2 Berlin     3382169
# 3 Madrid     2938723
# 4 Stockholm  1942362
#   Capital   Population
# 1 New York  17800000
# 2 Berlin     3382169
# 3 Madrid     2938723
# 4 Stockholm  1942362

# %% [markdown]
# ## Importing XML, JSON data into R

# %%
# working with xml file from url link
library(RCurl)
library(XML, lib.loc="~/R/win-library/3.4")
# library(RCurl, lib.loc="~/R/win-library/3.4")
fileURL <- "https://www.w3schools.com/xml/simple.xml"
xData <- getURL(fileURL)
doc <- xmlParse(xData)
rootNode <- xmlRoot(doc)
xmldataframe1 <- xmlToDataFrame(xData)
xmldataframe1
# working with local file
result <- xmlParse("data/books.xml")
print(result)
rootNode <- xmlRoot(result)
rootSize <- xmlSize(rootNode)
print(rootSize)
print(rootNode[1])
xmldataframe <- xmlToDataFrame("data/books.xml")
print(xmldataframe)
head(xmldataframe)
# Out:
#   name                        price
# 1 Belgian Waffles             $5.95
# 2 Strawberry Belgian Waffles  $7.95
# 3 Berry-Berry Belgian Waffles $8.95
# 4 French Toast                $4.50
# 5 Homestyle Breakfast         $6.95
#   description
# 1 Two of our famous Belgian Waffles with plenty of real maple syrup
# 2 Light Belgian waffles covered with strawberries and whipped cream
# 3 Light Belgian waffles covered with an assortment of fresh berries and whipped cream
# 4 Thick slices made from our homemade sourdough bread
# 5 Two eggs, bacon or sausage, toast, and our ever-popular hash browns
#   calories
# 1 650
# 2 900
# 3 900
# 4 600
# 5 950
# <?xml version="1.0"?>
# <RECORDS>
#   <EMPLOYEE>
#     <ID>1</ID>
#     <NAME>Rick</NAME>
#     <SALARY>623.3</SALARY>
#     <STARTDATE>1/1/2012</STARTDATE>
#     <DEPT>IT</DEPT>
#   </EMPLOYEE>
#   <EMPLOYEE>
#     <ID>2</ID>
#     <NAME>Dan</NAME>
#     <SALARY>515.2</SALARY>
#     <STARTDATE>9/23/2013</STARTDATE>
# ...

# %%
#install.packages("rjson", repos = "http://cran.us.r-project.org")
# Load the package required to read JSON files.
library("rjson", lib.loc="~/R/win-library/3.4")

# Give the input file name to the function.
result <- fromJSON(file = "data/JSN.json")

# Print the result.
print(result)
as.data.frame(result)
# Out:
# $ID
# [1] "1" "2" "3" "4" "5" "6" "7" "8"
#
# $Name
# [1] "Rick"     "Dan"      "Michelle" "Ryan"     "Gary"     "Nina"     "Simon"
# [8] "Guru"
#
# $Salary
# [1] "623.3"  "515.2"  "611"    "729"    "843.25" "578"    "632.8"  "722.5"
#
# $StartDate
# [1] "1/1/2012"   "9/23/2013"  "11/15/2014" "5/11/2014"  "3/27/2015"
# [6] "5/21/2013"  "7/30/2013"  "6/17/2014"
#
# $Dept
# [1] "IT"         "Operations" "IT"         "HR"         "Finance"
# [6] "IT"         "Operations" "Finance"
#   ID Name     Salary StartDate  Dept
# 1 1  Rick     623.3  1/1/2012   IT
# 2 2  Dan      515.2  9/23/2013  Operations
# 3 3  Michelle 611    11/15/2014 IT
# 4 4  Ryan     729    5/11/2014  HR
# 5 5  Gary     843.25 3/27/2015  Finance
# 6 6  Nina     578    5/21/2013  IT
# 7 7  Simon    632.8  7/30/2013  Operations
# 8 8  Guru     722.5  6/17/2014  Finance

# %% [markdown]
# ## Importing Data From HTML Tables Into R

# %% [markdown]
# ### Using httr packages

# %%
url  <- "https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_population"
# install.packages("httr", repos = "http://cran.us.r-project.org")
library(httr, lib.loc="~/R/win-library/3.4")
urldata <- GET(url)
data <- readHTMLTable(rawToChar(urldata$content),stringsAsFactors = FALSE, as.data.frame = TRUE)
head(data)
# Out:
# $`NULL`
#    Rank in the fifty states, 2017 Rank in all states & territories, 2010
# 1    7000100000000000000<U+2660>1           7000100000000000000<U+2660>1
# 2    7000200000000000000<U+2660>2           7000200000000000000<U+2660>2
# 3    7000300000000000000<U+2660>3           7000400000000000000<U+2660>4
# 4    7000400000000000000<U+2660>4           7000300000000000000<U+2660>3
# 5    7000500000000000000<U+2660>5           7000600000000000000<U+2660>6
# 6    7000600000000000000<U+2660>6           7000500000000000000<U+2660>5
# 7    7000700000000000000<U+2660>7           7000700000000000000<U+2660>7
# 8    7000800000000000000<U+2660>8           7000900000000000000<U+2660>9
# 9    7000900000000000000<U+2660>9          7001100000000000000<U+2660>10
# 10  7001100000000000000<U+2660>10           7000800000000000000<U+2660>8
# 11  7001110000000000000<U+2660>11          7001110000000000000<U+2660>11
# 12  7001120000000000000<U+2660>12          7001120000000000000<U+2660>12
# ...

# %%
library (plyr)
df <- ldply (data, data.frame)
dim(df)
head(df)
# Out:
# [1] 162  24
#   .id  Rank.in.the.fifty.states..2017 Rank.in.all.states...territories..2010
# 1 NULL 7000100000000000000<U+2660>1   7000100000000000000<U+2660>1
# 2 NULL 7000200000000000000<U+2660>2   7000200000000000000<U+2660>2
# 3 NULL 7000300000000000000<U+2660>3   7000400000000000000<U+2660>4
# 4 NULL 7000400000000000000<U+2660>4   7000300000000000000<U+2660>3
# 5 NULL 7000500000000000000<U+2660>5   7000600000000000000<U+2660>6
# 6 NULL 7000600000000000000<U+2660>6   7000500000000000000<U+2660>5
#   State.or.territory Population.estimate..July.1..2017.4.
# 1 California         39,536,653
# 2 Texas              28,304,596
# 3 Florida            20,984,400
# 4 New York           19,849,399
# 5 Pennsylvania       12,805,537
# 6 Illinois           12,802,023
#   Census.population..April.1..2010
# 1 37,252,895
# 2 25,146,105
# 3 18,804,623
# 4 19,378,087
# 5 12,702,887
# 6 12,831,549
#   Total.seats.in.House.of.Representatives..2013â..2023
# 1 7001530000000000000<U+2660>53
# ...

# %% [markdown]
# **further reference:** https://www.apress.com/in/book/9781461478997

# %% [markdown]
# ### Using rvest package (web scrapping)
#
# **rvest in action**

# %%
library(rvest)
# install.packages("xml2", repos = "http://cran.us.r-project.org")
library(xml2,lib.loc="~/R/win-library/3.4")
lego_movie <- read_html("http://www.imdb.com/title/tt1490017/")
#print(lego_movie)

# %%
lego_movie %>%
html_node("strong span") %>%
html_text() %>%
as.numeric()
# selector:
lego_movie %>%
html_nodes("#titleCast .itemprop span") %>%
html_text()
# The titles and authors of recent message board postings are stored in a the third table on the
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# [1] 7.8
#  [1] "Will Arnett"     "Elizabeth Banks" "Craig Berry"     "Alison Brie"
#  [5] "David Burrows"   "Anthony Daniels" "Charlie Day"     "Amanda Farinos"
#  [9] "Keith Ferguson"  "Will Ferrell"    "Will Forte"      "Dave Franco"
# [13] "Morgan Freeman"  "Todd Hansen"     "Jonah Hill"

# %% [markdown]
# #### Import data from wikipedia (Scrape an HTML Table)
# * html_nodes: Select parts of an html document using css selectors
# * html_table: Parse tables into data frames with html_table().
# * read_html: Read in the content from a .html file (For xml2 and rvest packages.)
# * `browseVignettes()` to check the any sample codes of the concepts

# %%
obesity = read_html("https://en.wikipedia.org/wiki/Obesity_in_the_United_States")
#Using rvest to Scrape an HTML Table by taking table number
obesity = obesity %>%
     html_nodes("table") %>%
     .[[2]]%>%
     html_table(fill=T)

# %%
dim(obesity)
head(obesity)
tail(obesity)
# Out:
# [1] 56  6
#   States, District,\n& Territories Obese adults (mid-2000s)
# 1 Alabama                          30.1%
# 2 Alaska                           27.3%
# 3 American Samoa                   
# 4 Arizona                          23.3%
# 5 Arkansas                         28.1%
# 6 California                       23.1%
#   Obese adults (2016)[52][57] Overweight (incl. obese) adults\n(mid-2000s)
# 1 35.7%                       65.4%
# 2 31.4%                       64.5%
# 3 75%[56]                     95%[59]
# 4 29.0%                       59.5%
# 5 35.7%                       64.7%
# 6 25.0%                       59.4%
#   Obese children and adolescents\n(mid-2000s)[58] Obesity rank
# 1 16.7%                                           3
# 2 11.1%                                           14
# 3 35%[56][60]                                     
# 4 12.2%                                           40
# 5 16.4%                                           9
# ...

# %% [markdown]
# #### Import data from wikipedia (Using xpath)

# %% [markdown]
# **Steps**
# 1. *browse to the desired page and locate the table*
# 2. *right clicked on the table you want and chose “inspect element”*
# 2. *choose “copy XPath”*
# 4. *Paste that XPath into the appropriate spot as shown in the code below*

# %%
url <- "http://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_population"
population <- url %>%
  read_html() %>%
  html_nodes(xpath='//*[@id="mw-content-text"]/div/table[1]') %>%
  html_table()
population <- population[[1]]

head(population)
tail(population)
# //*[@id="mw-content-text"]/div/table[1]/tbody/tr[7]/td[3]
# Out:
#   Rank in the fifty states, 2017 Rank in all states & territories, 2010
# 1 7000100000000000000<U+2660>1   7000100000000000000<U+2660>1
# 2 7000200000000000000<U+2660>2   7000200000000000000<U+2660>2
# 3 7000300000000000000<U+2660>3   7000400000000000000<U+2660>4
# 4 7000400000000000000<U+2660>4   7000300000000000000<U+2660>3
# 5 7000500000000000000<U+2660>5   7000600000000000000<U+2660>6
# 6 7000600000000000000<U+2660>6   7000500000000000000<U+2660>5
#   State or territory Population estimate, July 1, 2017[4]
# 1 California         39,536,653
# 2 Texas              28,304,596
# 3 Florida            20,984,400
# 4 New York           19,849,399
# 5 Pennsylvania       12,805,537
# 6 Illinois           12,802,023
#   Census population, April 1, 2010
# 1 37,252,895
# 2 25,146,105
# 3 18,804,623
# 4 19,378,087
# 5 12,702,887
# 6 12,831,549
#   Total seats in House of Representatives, 20132023
# 1 7001530000000000000<U+2660>53
# 2 7001360000000000000<U+2660>36
# ...

# %% [markdown]
# **Further References:**  https://stat4701.github.io/edav/2015/04/02/rvest_tutorial/

# %% [markdown]
# ## Importing Data From Other Statistical softwares
# * Packages
#     * haven
#     * foreign
#     * Hmisc
# * From SAS
# * From Stata
# * From SPSS

# %% [markdown]
# ### haven package

# %% [markdown]
# #### From SAS

# %%
# install.packages("haven", repos = "http://cran.us.r-project.org")
library(haven)
ontime <- read_sas("data/sales.sas7bdat")
head(ontime)
# Out:
# Warning message:
# "package 'haven' was built under R version 3.4.3"
#   purchase age gender income
# 1 0        41  Female Low
# 2 0        47  Female Low
# 3 1        41  Female Low
# 4 1        39  Female Low
# 5 0        32  Female Low
# 6 0        32  Female Low

# %% [markdown]
# #### From Stata

# %%
trade <- read_stata("data/trade.dta")
head(trade)
trade <- read_dta("data/trade.dta")
head(trade)
# Out:
#   Date Import   Weight_I Export    Weight_E
# 1 10   37664782 54029106  54505513  93350013
# 2  9   16316512 21584365 102700010 158000010
# 3  8   11082246 14526089  37935000  88000000
# 4  7   35677943 55034932  48515008 112000005
# 5  6    9879878 14806865  71486545 131800000
# 6  5    1539992  1749318  12311696  18500014
#   Date Import   Weight_I Export    Weight_E
# 1 10   37664782 54029106  54505513  93350013
# 2  9   16316512 21584365 102700010 158000010
# 3  8   11082246 14526089  37935000  88000000
# 4  7   35677943 55034932  48515008 112000005
# 5  6    9879878 14806865  71486545 131800000
# 6  5    1539992  1749318  12311696  18500014

# %% [markdown]
# #### From SPSS

# %%
Anxiety <- read_spss("data/Anxiety 2.sav")
Anxiety
# Out:
#    subject anxiety tension trial1 trial2 trial3 trial4
# 1   1      1       1       18     14     12     6
# 2   2      1       1       19     12      8     4
# 3   3      1       1       14     10      6     2
# 4   4      1       2       16     12     10     4
# 5   5      1       2       12      8      6     2
# 6   6      1       2       18     10      5     1
# 7   7      2       1       16     10      8     4
# 8   8      2       1       18      8      4     1
# 9   9      2       1       16     12      6     2
# 10 10      2       2       19     16     10     8
# 11 11      2       2       16     14     10     9
# 12 12      2       2       16     12      8     8

# %% [markdown]
# ### foreign package

# %%
library(foreign)
# from SAS
#nstall.packages("sas7bdat", repos = "http://cran.us.r-project.org")
library(sas7bdat)
mydata <- read.sas7bdat("data/sales.sas7bdat") 
head(mydata)
# from stata
mydata <- read.dta("data/trade.dta")
head(mydata)
# from SPSS
mySPSSData <- read.spss("data/Anxiety 2.sav",
                       to.data.frame=TRUE,
                       use.value.labels=FALSE)
head(mySPSSData)
# Out:
#   purchase age gender income
# 1 0        41  Female Low
# 2 0        47  Female Low
# 3 1        41  Female Low
# 4 1        39  Female Low
# 5 0        32  Female Low
# 6 0        32  Female Low
#   Date       Import   Weight_I Export    Weight_E
# 1 2013-12-31 37664782 54029106  54505513  93350013
# 2 2012-12-31 16316512 21584365 102700010 158000010
# 3 2011-12-31 11082246 14526089  37935000  88000000
# 4 2010-12-31 35677943 55034932  48515008 112000005
# 5 2009-12-31  9879878 14806865  71486545 131800000
# 6 2008-12-31  1539992  1749318  12311696  18500014
# re-encoding from CP1252
#   subject anxiety tension trial1 trial2 trial3 trial4
# 1 1       1       1       18     14     12     6
# 2 2       1       1       19     12      8     4
# 3 3       1       1       14     10      6     2
# 4 4       1       2       16     12     10     4
# 5 5       1       2       12      8      6     2
# 6 6       1       2       18     10      5     1

# %% [markdown]
# ### Hmisc package

# %%
# from SAS
# from stata
# from SPSS

# %% [markdown]
# **further references:** https://datascienceplus.com/get-your-data-into-r/
